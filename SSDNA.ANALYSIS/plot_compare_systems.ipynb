# %%
import numpy as np
import matplotlib.pyplot as plt


data_dna = np.loadtxt('dna_med_val_0.txt')
data_rpa = np.loadtxt('rpa_dna_med_val_0.txt')
data_dna_c = np.loadtxt('dna_c_med_val_0.txt')
data_dna_chst = np.loadtxt('dna_c_hst_med_val_0.txt')

fig, axp = plt.subplots(figsize=(12, 8))

length_m = [25, 30, 40, 45, 60, 80, 100]
length = [15, 25, 30, 40, 45, 60, 80, 100]
length_s = [15, 25, 30, 45]

axp.scatter(length, data_dna, label='ssDNA',
            color='black', s=200, edgecolor='black')
axp.scatter(length, data_rpa, label='RPA+ssDNA',
            color='gray', s=200, edgecolor='black')
axp.scatter(length_m, data_dna_c, label='ssDNA i-i+23 --> 55 \u212B',
            color='crimson', s=200, edgecolor='black')
axp.scatter(length_m, data_dna_chst, label='ssDNA i-i+11 --> 66 \u212B',
            color='cornflowerblue', s=200, edgecolor='black')
axp.legend(fontsize=24)

axp.set_title('dihedral = 0.0', fontsize=30, fontweight='bold')
axp.set_ylabel('Distance (nm)', fontsize=28)
axp.set_xlabel('DNA length (nt)', fontsize=28)
axp.xaxis.tick_bottom()
axp.yaxis.tick_left()
axp.tick_params(axis='both', which='major', labelsize=22)

spines_to_keep = ['bottom', 'left']
spines_to_remove = ['top', 'right']

for spine in spines_to_remove:
    axp.spines[spine].set_visible(False)

coefficients_d = np.polyfit(length, data_dna, 1)
fitted_line_d = np.polyval(coefficients_d, length)

coefficients_cd = np.polyfit(length_m, data_dna_c, 1)
fitted_line_cd = np.polyval(coefficients_cd, length_m)

coefficients_chstd = np.polyfit(length_m, data_dna_chst, 1)
fitted_line_chstd = np.polyval(coefficients_chstd, length_m)

coefficients_r = np.polyfit(length, data_rpa, 1)
fitted_line_r = np.polyval(coefficients_r, length)

axp.plot(length, fitted_line_d, color='black')
axp.plot(length, fitted_line_r, color='gray')
axp.plot(length_m, fitted_line_cd, color='crimson')
axp.plot(length_m, fitted_line_chstd, color='cornflowerblue')

fig.savefig('rpa_ssdna_compare_systems_all_dih_0.png',
            dpi=300, bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt


data_dna = np.loadtxt('dna_med_val_4.txt')
data_rpa = np.loadtxt('rpa_dna_med_val_4.txt')
data_dna_c = np.loadtxt('dna_c_med_val_4.txt')
data_dna_chst = np.loadtxt('dna_c_hst_med_val_4.txt')

fig, axp = plt.subplots(figsize=(12, 8))

length_m = [25, 30, 40, 45, 60, 80, 100]
length = [15, 25, 30, 40, 45, 60, 80, 100]
length_s = [15, 25, 30, 45]

axp.scatter(length, data_dna, label='ssDNA',
            color='black', s=200, edgecolor='black')
axp.scatter(length, data_rpa, label='RPA+ssDNA',
            color='gray', s=200, edgecolor='black')
axp.scatter(length_m, data_dna_c, label='ssDNA i-i+23 --> 55 \u212B',
            color='crimson', s=200, edgecolor='black')
axp.scatter(length_m, data_dna_chst, label='ssDNA i-i+11 --> 66 \u212B',
            color='cornflowerblue', s=200, edgecolor='black')
axp.legend(fontsize=24)

axp.set_title('dihedral = 0.4', fontsize=30, fontweight='bold')
axp.set_ylabel('Distance (nm)', fontsize=28)
axp.set_xlabel('DNA length (nt)', fontsize=28)
axp.xaxis.tick_bottom()
axp.yaxis.tick_left()
axp.tick_params(axis='both', which='major', labelsize=22)

spines_to_keep = ['bottom', 'left']
spines_to_remove = ['top', 'right']

for spine in spines_to_remove:
    axp.spines[spine].set_visible(False)

coefficients_d = np.polyfit(length, data_dna, 1)
fitted_line_d = np.polyval(coefficients_d, length)

coefficients_cd = np.polyfit(length_m, data_dna_c, 1)
fitted_line_cd = np.polyval(coefficients_cd, length_m)

coefficients_chstd = np.polyfit(length_m, data_dna_chst, 1)
fitted_line_chstd = np.polyval(coefficients_chstd, length_m)

coefficients_r = np.polyfit(length, data_rpa, 1)
fitted_line_r = np.polyval(coefficients_r, length)

axp.plot(length, fitted_line_d, color='black')
axp.plot(length, fitted_line_r, color='gray')
axp.plot(length_m, fitted_line_cd, color='crimson')
axp.plot(length_m, fitted_line_chstd, color='cornflowerblue')

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.optimize import curve_fit
def scaling_law1(x, A, v):
    return 0.6 * x**v
def scaling_law2(x, A, v):
    return A * x**v
def scaling_law3(x, A, v):
    return A * x**v
def scaling_law4(x, A, v):
    return A * x**v

data_dna = np.loadtxt('dna_med_val_0.txt')
data_rpa = np.loadtxt('rpa_dna_A_med_val_0.txt')
data_dna_c = np.loadtxt('dna_c_med_val_0.txt')
data_dna_chst = np.loadtxt('dna_c_hst_med_val_0.txt')
data_dna_cst = np.loadtxt('dna_c_st_med_val_0.txt')
data_two_rpa_face = np.loadtxt('two_rpa_dna_med_val_0.txt')

fig, axp = plt.subplots(figsize=(20, 10))

length_m = [25, 30, 40, 45, 60, 80, 100]
length = [15, 25, 30, 40, 45, 60, 80, 100]
length_mm = [15, 25, 30, 40, 45, 60, 80, 100]
length_two = [60, 80, 100]

axp.scatter(length, data_dna, label='ssDNA',
            color='black', s=300, edgecolor='black')
axp.scatter(length_m, data_dna_c, label='ssDNA i-i+23 --> 55 \u212B',
            color='crimson', s=300, edgecolor='black')
axp.scatter(length_m, data_dna_chst, label='ssDNA i-i+11 --> 66 \u212B',
            color='cornflowerblue', s=300, edgecolor='black')
axp.scatter(length_mm, data_rpa, label='RPA+ssDNA',
            color='gray', s=300, edgecolor='black')
#axp.scatter(length_m, data_dna_cst, label='ssDNA i-i+23 --> 122 \u212B', color='mediumseagreen', s=300, edgecolor='black')
axp.scatter(length_two, data_two_rpa_face, label='two rpa', color='darkorange', s=300, edgecolor='black')
#axp.legend(fontsize=24, loc='upper left')

axp.set_title('dihedral = 0.0', fontsize=30, fontweight='bold')
axp.set_ylabel('Distance (nm)', fontsize=28)
axp.set_xlabel('DNA length (nt)', fontsize=28)
axp.xaxis.tick_bottom()
axp.yaxis.tick_left()
axp.tick_params(axis='both', which='major', labelsize=22)

spines_to_keep = ['bottom', 'left']
spines_to_remove = ['top', 'right']

for spine in spines_to_remove:
    axp.spines[spine].set_visible(False)
    
params_d, covar_d = curve_fit(scaling_law1, length, data_dna)
params_cd, covar_cd = curve_fit(scaling_law3, length_m, data_dna_c)
params_chstd, covar_chstd = curve_fit(scaling_law2, length_m, data_dna_chst)
params_r, covar_r = curve_fit(scaling_law2, length_mm, data_rpa)
params_cstd, covar_cstd = curve_fit(scaling_law4, length_m, data_dna_cst)

A_d, v_d = params_d
A_cd, v_cd = params_cd
A_chstd, v_chstd = params_chstd
A_r, v_r = params_r
A_cstd, v_cstd = params_cstd

y_fit_d = scaling_law1(length, A_d, v_d)
y_fit_cd = scaling_law3(length_m, A_cd, v_cd)
y_fit_chstd = scaling_law2(length_m, A_chstd, v_chstd)
y_fit_r = scaling_law2(length_mm, A_r, v_r)
y_fit_cstd = scaling_law4(length_m, A_cstd, v_cstd)
'''
axp.plot(length, y_fit_d, color='black', label='$\\nu$ = {:>3.2f}'.format(v_d), linewidth=6)
axp.plot(length_m, y_fit_cd, color='crimson', label='$\\nu$ = {:>3.2f}'.format(v_cd), linewidth=6)
axp.plot(length_m, y_fit_chstd, color='cornflowerblue', label='$\\nu$ = {:>3.2f}'.format(v_chstd), linewidth=6)
axp.plot(length_mm, y_fit_r, color='gray',label='$\\nu$ = {:>3.2f}'.format(v_r), linewidth=6)
axp.plot(length_m, y_fit_cstd, color='mediumseagreen', label='$\\nu$ = {:>3.2f}'.format(v_cstd), linewidth=6)
'''
axp.legend(fontsize=20, loc='lower right', ncol=2)

axp.plot(length, y_fit_d, color='black', linewidth=6)
axp.plot(length_m, y_fit_cd, color='crimson', linewidth=6)
axp.plot(length_m, y_fit_chstd, color='cornflowerblue', linewidth=6)
axp.plot(length_mm, y_fit_r, color='gray',linewidth=6)
#axp.plot(length_m, y_fit_cstd, color='mediumseagreen',linewidth=6)
fig.savefig('all_models_0.png', dpi=300, bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.optimize import curve_fit
def scaling_law1(x, A, v):
    return 0.6 * x**v
def scaling_law2(x, A, v):
    return A * x**v
def scaling_law3(x, A, v):
    return A * x**v
def scaling_law4(x, A, v):
    return A * x**v

data_dna = np.loadtxt('dna_med_val_4.txt')
data_rpa = np.loadtxt('rpa_dna_A_med_val_4.txt')
data_dna_c = np.loadtxt('dna_c_med_val_4.txt')
data_dna_chst = np.loadtxt('dna_c_hst_med_val_4.txt')
data_dna_cst = np.loadtxt('dna_c_st_med_val_4.txt')
data_two_rpa_face = np.loadtxt('two_rpa_dna_med_val_4.txt')

fig, axp = plt.subplots(figsize=(20, 10))

length_m = [25, 30, 40, 45, 60, 80, 100]
length = [15, 25, 30, 40, 45, 60, 80, 100]
length_mm = [15, 25, 30, 40, 45, 60, 80, 100]
length_two = [60, 80, 100]

axp.scatter(length, data_dna, label='ssDNA',
            color='black', s=300, edgecolor='black')
axp.scatter(length_m, data_dna_c, label='ssDNA i-i+23 --> 55 \u212B',
            color='crimson', s=300, edgecolor='black')
axp.scatter(length_m, data_dna_chst, label='ssDNA i-i+11 --> 66 \u212B',
            color='cornflowerblue', s=300, edgecolor='black')
axp.scatter(length_mm, data_rpa, label='RPA+ssDNA',
            color='gray', s=300, edgecolor='black')
axp.scatter(length_m, data_dna_cst, label='ssDNA i-i+23 --> 122 \u212B', color='mediumseagreen', s=300, edgecolor='black')
axp.scatter(length_two, data_two_rpa_face, label='two rpa', color='darkorange', s=300, edgecolor='black')
#axp.legend(fontsize=24, loc='upper left')

axp.set_title('dihedral = 0.4', fontsize=30, fontweight='bold')
axp.set_ylabel('Distance (nm)', fontsize=28)
axp.set_xlabel('DNA length (nt)', fontsize=28)
axp.xaxis.tick_bottom()
axp.yaxis.tick_left()
axp.tick_params(axis='both', which='major', labelsize=22)

spines_to_keep = ['bottom', 'left']
spines_to_remove = ['top', 'right']

for spine in spines_to_remove:
    axp.spines[spine].set_visible(False)
    
params_d, covar_d = curve_fit(scaling_law1, length, data_dna)
params_cd, covar_cd = curve_fit(scaling_law3, length_m, data_dna_c)
params_chstd, covar_chstd = curve_fit(scaling_law2, length_m, data_dna_chst)
params_r, covar_r = curve_fit(scaling_law2, length_mm, data_rpa)
params_cstd, covar_cstd = curve_fit(scaling_law4, length_m, data_dna_cst)

A_d, v_d = params_d
A_cd, v_cd = params_cd
A_chstd, v_chstd = params_chstd
A_r, v_r = params_r
A_cstd, v_cstd = params_cstd

y_fit_d = scaling_law1(length, A_d, v_d)
y_fit_cd = scaling_law3(length_m, A_cd, v_cd)
y_fit_chstd = scaling_law2(length_m, A_chstd, v_chstd)
y_fit_r = scaling_law2(length_mm, A_r, v_r)
y_fit_cstd = scaling_law4(length_m, A_cstd, v_cstd)
'''
axp.plot(length, y_fit_d, color='black', label='$\\nu$ = {:>3.2f}'.format(v_d), linewidth=6)
axp.plot(length_m, y_fit_cd, color='crimson', label='$\\nu$ = {:>3.2f}'.format(v_cd), linewidth=6)
axp.plot(length_m, y_fit_chstd, color='cornflowerblue', label='$\\nu$ = {:>3.2f}'.format(v_chstd), linewidth=6)
axp.plot(length_mm, y_fit_r, color='gray',label='$\\nu$ = {:>3.2f}'.format(v_r), linewidth=6)
axp.plot(length_m, y_fit_cstd, color='mediumseagreen', label='$\\nu$ = {:>3.2f}'.format(v_cstd), linewidth=6)
'''
axp.legend(fontsize=20, loc='lower right', ncol=2)

axp.plot(length, y_fit_d, color='black', linewidth=6)
axp.plot(length_m, y_fit_cd, color='crimson', linewidth=6)
axp.plot(length_m, y_fit_chstd, color='cornflowerblue', linewidth=6)
axp.plot(length_mm, y_fit_r, color='gray',linewidth=6)
axp.plot(length_m, y_fit_cstd, color='mediumseagreen',linewidth=6)
fig.savefig('all_models_4.png', dpi=300, bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.optimize import curve_fit
'''
def scaling_law1(x, A, v):
    return A * x**v
def scaling_law2(x, A, v):
    return 6.6+ A * x**v
def scaling_law3(x, A, v):
    return 2.5+ A * x**v
def scaling_law4(x, A, v):
    return 11+ A * x**v
    
'''

data_dna = np.loadtxt('dna_med_val_4.txt')
data_rpa = np.loadtxt('rpa_dna_med_val_4.txt')
data_dna_c = np.loadtxt('dna_c_med_val_4.txt')
data_dna_chst = np.loadtxt('dna_c_hst_med_val_4.txt')
data_dna_cst = np.loadtxt('dna_c_st_med_val_4.txt')

fig, axp = plt.subplots(figsize=(16, 10))

length_m = [25, 30, 40, 45, 60, 80, 100]
length = [15, 25, 30, 40, 45, 60, 80, 100]
length_mm = [25, 30, 40, 45, 60, 80, 100]

axp.scatter(length, data_dna, label='ssDNA',
            color='black', s=200, edgecolor='black')
axp.scatter(length_m, data_dna_c, label='ssDNA i-i+23 --> 55 \u212B',
            color='crimson', s=200, edgecolor='black')
axp.scatter(length_m, data_dna_chst, label='ssDNA i-i+11 --> 66 \u212B',
            color='cornflowerblue', s=200, edgecolor='black')
axp.scatter(length, data_rpa, label='RPA+ssDNA',
            color='gray', s=200, edgecolor='black')
axp.scatter(length_mm, data_dna_cst, label='ssDNA i-i+23 --> 122 \u212B', color='mediumseagreen', s=200, edgecolor='black')
#axp.legend(fontsize=24, loc='upper left')

axp.set_title('dihedral = 0.4', fontsize=30, fontweight='bold')
axp.set_ylabel('Distance (nm)', fontsize=28)
axp.set_xlabel('DNA length (nt)', fontsize=28)
axp.xaxis.tick_bottom()
axp.yaxis.tick_left()
axp.tick_params(axis='both', which='major', labelsize=22)

spines_to_keep = ['bottom', 'left']
spines_to_remove = ['top', 'right']

for spine in spines_to_remove:
    axp.spines[spine].set_visible(False)
    
params_d, covar_d = curve_fit(scaling_law1, length, data_dna)
params_cd, covar_cd = curve_fit(scaling_law3, length_m, data_dna_c)
params_chstd, covar_chstd = curve_fit(scaling_law2, length_m, data_dna_chst)
params_r, covar_r = curve_fit(scaling_law1, length, data_rpa)
params_cstd, covar_cstd = curve_fit(scaling_law4, length_mm, data_dna_cst)

A_d, v_d = params_d
A_cd, v_cd = params_cd
A_chstd, v_chstd = params_chstd
A_r, v_r = params_r
A_cstd, v_cstd = params_cstd

y_fit_d = scaling_law1(length, A_d, v_d)
y_fit_cd = scaling_law3(length_m, A_cd, v_cd)
y_fit_chstd = scaling_law2(length_m, A_chstd, v_chstd)
y_fit_r = scaling_law1(length, A_r, v_r)
y_fit_cstd = scaling_law4(length_mm, A_cstd, v_cstd)

axp.plot(length, y_fit_d, color='black', label='$\\nu$ = {:>3.2f}'.format(v_d), linewidth=6)
axp.plot(length_m, y_fit_cd, color='crimson', label='$\\nu$ = {:>3.2f}'.format(v_cd), linewidth=6)
axp.plot(length_m, y_fit_chstd, color='cornflowerblue', label='$\\nu$ = {:>3.2f}'.format(v_chstd), linewidth=6)
axp.plot(length, y_fit_r, color='gray',label='$\\nu$ = {:>3.2f}'.format(v_r), linewidth=6)
axp.plot(length_mm, y_fit_cstd, color='mediumseagreen', label='$\\nu$ = {:>3.2f}'.format(v_cstd), linewidth=6)
axp.legend(fontsize=20, loc='lower right', ncol=2)
fig.savefig('all_models_4.png', dpi=300, bbox_inches='tight')
# Out:
# /home_b/gargi/miniconda3/lib/python3.9/site-packages/scipy/optimize/minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.optimize import curve_fit
def scaling_law1(x, A, v):
    return A * x**v
def scaling_law2(x, A, v):
    return 6.6+ A * x**v
def scaling_law3(x, A, v):
    return 2.5+ A * x**v

data_dna = np.loadtxt('dna_med_val_0.txt')
data_rpa = np.loadtxt('rpa_dna_med_val_0.txt')
data_dna_c = np.loadtxt('dna_c_med_val_0.txt')
data_dna_chst = np.loadtxt('dna_c_hst_med_val_0.txt')

fig, axp = plt.subplots(figsize=(16, 10))

length_m = [25, 30, 40, 45, 60, 80, 100]
length = [15, 25, 30, 40, 45, 60, 80, 100]

axp.scatter(length, data_dna, label='ssDNA',
            color='black', s=200, edgecolor='black')
axp.scatter(length_m, data_dna_c, label='ssDNA i-i+23 --> 55 \u212B',
            color='crimson', s=200, edgecolor='black')
axp.scatter(length_m, data_dna_chst, label='ssDNA i-i+11 --> 66 \u212B',
            color='cornflowerblue', s=200, edgecolor='black')
axp.scatter(length, data_rpa, label='RPA+ssDNA',
            color='gray', s=200, edgecolor='black')
#axp.legend(fontsize=24, loc='upper left')

axp.set_title('dihedral = 0.0', fontsize=30, fontweight='bold')
axp.set_ylabel('Distance (nm)', fontsize=28)
axp.set_xlabel('DNA length (nt)', fontsize=28)
axp.xaxis.tick_bottom()
axp.yaxis.tick_left()
axp.tick_params(axis='both', which='major', labelsize=22)

spines_to_keep = ['bottom', 'left']
spines_to_remove = ['top', 'right']

for spine in spines_to_remove:
    axp.spines[spine].set_visible(False)
    
params_d, covar_d = curve_fit(scaling_law1, length, data_dna)
params_cd, covar_cd = curve_fit(scaling_law3, length_m, data_dna_c)
params_chstd, covar_chstd = curve_fit(scaling_law2, length_m, data_dna_chst)
params_r, covar_r = curve_fit(scaling_law1, length, data_rpa)

A_d, v_d = params_d
A_cd, v_cd = params_cd
A_chstd, v_chstd = params_chstd
A_r, v_r = params_r

y_fit_d = scaling_law1(length, A_d, v_d)
y_fit_cd = scaling_law3(length_m, A_cd, v_cd)
y_fit_chstd = scaling_law2(length_m, A_chstd, v_chstd)
y_fit_r = scaling_law1(length, A_r, v_r)

axp.plot(length, y_fit_d, color='black', label='$\\nu$ = {:>3.2f}'.format(v_d), linewidth=6)
axp.plot(length_m, y_fit_cd, color='crimson', label='$\\nu$ = {:>3.2f}'.format(v_cd), linewidth=6)
axp.plot(length_m, y_fit_chstd, color='cornflowerblue', label='$\\nu$ = {:>3.2f}'.format(v_chstd), linewidth=6)
axp.plot(length, y_fit_r, color='gray',label='$\\nu$ = {:>3.2f}'.format(v_r), linewidth=6)
axp.legend(fontsize=20, loc='lower right', ncol=2)
