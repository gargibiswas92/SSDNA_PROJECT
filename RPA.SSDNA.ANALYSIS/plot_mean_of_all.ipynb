# %%
import numpy as np   
import matplotlib.pyplot as plt  
import seaborn as sns 

fig, ax = plt.subplots(1, 2, figsize=(10,8))
indeces=["40_7_CH_REP_1.6", "40_7_CH_REP_1.7"]
lab = ["rad = 1.6", "rad=1.7"]
ind = 0
for item in indeces:
 folder="/home_b/gargi/project_RPA_edwin/MDRUN/ONLY.DNA.MODIFICATIONS/RUNS.TO.SHOW/DNA_"+item+"/output/Traj/"
 for i in range(1,11):
    name=folder+"end_dis_"+str(i)+".txt"
    data=np.loadtxt(name)
    val=data[:,1]
    valp = val[40000:]
    mean = np.mean(val)
    std = np.std(val)
    ax[ind].scatter([0], mean, s=200, edgecolor='black')
    ax[ind].set_title(lab[ind])
 ind = ind + 1
 
fig.savefig('lowsalt_two_rad_N.png', dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,8))
indeces=["40_0_CH_REP_1.6", "40_0_CH_REP_1.7"]
lab = ["rad = 1.6", "rad=1.7"]
ind = 0
for item in indeces:
 folder="/home_b/gargi/project_RPA_edwin/MDRUN/ONLY.DNA.MODIFICATIONS/RUNS.TO.SHOW/DNA_"+item+"/output/Traj/"
 for i in range(1,11):
    name=folder+"end_dis_"+str(i)+".txt"
    data=np.loadtxt(name)
    val=data[:,1]
    valp = val[40000:]
    mean = np.mean(val)
    std = np.std(val)
    ax[ind].scatter([0], mean, s=200, edgecolor='black')
    ax[ind].set_title(lab[ind])
 ind = ind + 1
 
fig.savefig('highsalt_two_rad_N.png', dpi=300, bbox_inches='tight')
