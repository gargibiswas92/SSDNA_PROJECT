# %%
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt 


list = ['40_7_CH_REP_1.5', '40_0_CH_REP_1.5']
length = ['k$_{D}$ = 0.7', 'k$_{D}$ = 0.0']

xtick_pos = np.array([0, 1])
cmap = sns.color_palette("Set2")

data0_15, median_dna_15, std_dna_15 =[], [], []

for ll in list:
    name="/trajectories/gargi/RPA_Ed/RESULTS.ANALYSIS/end_to_end_"+ll+".txt"
    data = np.loadtxt(name)
    mask = np.isnan(data)
    data_n = data[~mask]
    #data_n = data_n[data_n < 100.0]
    dt=data_n/10
    me1=np.median(dt)
    sd1=np.std(dt)
    median_dna_15.append(me1)
    std_dna_15.append(sd1)
    data0_15.append(dt)
    
fig, ax = plt.subplots(figsize=(12,8))
    
sns.violinplot(data=data0_15, width=0.8, ax=ax, palette=cmap, split=True, scale="width")
ax.set_xticks(xtick_pos, length, fontsize=24, fontweight='bold')
ax.set_ylabel('Distance (nm)', fontsize=28)

ax.set_title('Radius = 1.5', fontsize=30, fontweight='bold')
ax.xaxis.tick_bottom()
ax.yaxis.tick_left()
ax.tick_params(axis='both', which='major', labelsize=22)

spines_to_keep = ['bottom', 'left']
spines_to_remove = ['top', 'right']

for spine in spines_to_remove:
    ax.spines[spine].set_visible(False)

# %%
fig, ax = plt.subplots(figsize=(12,8))
length = ['k$_{D}$ = 0.7', 'k$_{D}$ = 0.0']
    
x = [0, 1]
rects = ax.bar(x, median_dna_15, width=0.25, yerr=std_dna_15, label=median_dna_15,capsize=6)
ax.bar_label(rects, fmt='%3.2f', padding=3, fontsize=24, fontweight='bold')
ax.set_xticks(xtick_pos, length, fontsize=24, fontweight='bold')
ax.set_ylabel('Distance (nm)', fontsize=28)

ax.set_title('Radius = 1.5 A', fontsize=30, fontweight='bold')
ax.xaxis.tick_bottom()
ax.yaxis.tick_left()
ax.tick_params(axis='both', which='major', labelsize=22)

spines_to_keep = ['bottom', 'left']
spines_to_remove = ['top', 'right']

for spine in spines_to_remove:
    ax.spines[spine].set_visible(False)
    
ax.set_ylim(4, 12.5)
fig.savefig('ssDNA_e_to_e_15.png', dpi=300, bbox_inches='tight')

# %%
list = ['40_7_CH_REP_1.6', '40_0_CH_REP_1.6']

xtick_pos = np.array([0, 1])
cmap = sns.color_palette("Set2")

data0_16, median_dna_16, std_dna_16 =[], [], []

for ll in list:
    name="/trajectories/gargi/RPA_Ed/RESULTS.ANALYSIS/end_to_end_"+ll+".txt"
    data = np.loadtxt(name)
    mask = np.isnan(data)
    data_n = data[~mask]
    #data_n = data_n[data_n < 100.0]
    dt=data_n/10
    me1=np.median(dt)
    sd1=np.std(dt)
    median_dna_16.append(me1)
    std_dna_16.append(sd1)
    data0_16.append(dt)
    
fig, ax = plt.subplots(figsize=(12,8))
    
sns.violinplot(data=data0_16, width=0.8, ax=ax, palette=cmap, split=True, scale="width")
ax.set_xticks(xtick_pos, length, fontsize=24, rotation = 45)
ax.set_ylabel('Distance (nm)', fontsize=28)

ax.set_title('Radius = 1.6', fontsize=30, fontweight='bold')
ax.xaxis.tick_bottom()
ax.yaxis.tick_left()
ax.tick_params(axis='both', which='major', labelsize=22)

spines_to_keep = ['bottom', 'left']
spines_to_remove = ['top', 'right']

for spine in spines_to_remove:
    ax.spines[spine].set_visible(False)

# %%
fig, ax = plt.subplots(figsize=(12,8))
length = ['k$_{D}$ = 0.7', 'k$_{D}$ = 0.0']
    
x = [0, 1]
rects = ax.bar(x, median_dna_16, width=0.25, yerr=std_dna_16, label=median_dna_16,capsize=6)
ax.bar_label(rects, fmt='%3.2f', padding=3, fontsize=24, fontweight='bold')
ax.set_xticks(xtick_pos, length, fontsize=24, fontweight='bold')
ax.set_ylabel('Distance (nm)', fontsize=28)

ax.set_title('Radius = 1.6 A', fontsize=30, fontweight='bold')
ax.xaxis.tick_bottom()
ax.yaxis.tick_left()
ax.tick_params(axis='both', which='major', labelsize=22)

spines_to_keep = ['bottom', 'left']
spines_to_remove = ['top', 'right']

for spine in spines_to_remove:
    ax.spines[spine].set_visible(False)
    
ax.set_ylim(4, 12.5)
fig.savefig('ssDNA_e_to_e_16.png', dpi=300, bbox_inches='tight')

# %%
list = ['40_7_CH_REP_1.7', '40_0_CH_REP_1.7']
length = ['DIH = 0.7', 'DIH = 0.0' ]

xtick_pos = np.array([0, 1])
cmap = sns.color_palette("Set2")

data0_17, median_dna_17, std_dna_17 =[], [], []

for ll in list:
    name="/trajectories/gargi/RPA_Ed/RESULTS.ANALYSIS/end_to_end_"+ll+".txt"
    data = np.loadtxt(name)
    mask = np.isnan(data)
    data_n = data[~mask]
    #data_n = data_n[data_n < 100.0]
    dt=data_n/10
    me1=np.median(dt)
    sd1=np.std(dt)
    median_dna_17.append(me1)
    std_dna_17.append(sd1)
    data0_17.append(dt)
    
fig, ax = plt.subplots(figsize=(12,8))
    
sns.violinplot(data=data0_17, width=0.8, ax=ax, palette=cmap, split=True, scale="width")
ax.set_xticks(xtick_pos, length, fontsize=24, rotation = 45)
ax.set_ylabel('Distance (nm)', fontsize=28)

ax.set_title('Radius = 1.7', fontsize=30, fontweight='bold')
ax.xaxis.tick_bottom()
ax.yaxis.tick_left()
ax.tick_params(axis='both', which='major', labelsize=22)

spines_to_keep = ['bottom', 'left']
spines_to_remove = ['top', 'right']

for spine in spines_to_remove:
    ax.spines[spine].set_visible(False)

# %%
fig, ax = plt.subplots(figsize=(12,8))
length = ['k$_{D}$ = 0.7', 'k$_{D}$ = 0.0']
    
x = [0, 1]
rects = ax.bar(x, median_dna_17, width=0.25, yerr=std_dna_17, label=median_dna_17,capsize=6)
ax.bar_label(rects, fmt='%3.2f', padding=3, fontsize=24, fontweight='bold')
ax.set_xticks(xtick_pos, length, fontsize=24, fontweight='bold')
ax.set_ylabel('Distance (nm)', fontsize=28)

ax.set_title('Radius = 1.7 A', fontsize=30, fontweight='bold')
ax.xaxis.tick_bottom()
ax.yaxis.tick_left()
ax.tick_params(axis='both', which='major', labelsize=22)

spines_to_keep = ['bottom', 'left']
spines_to_remove = ['top', 'right']

for spine in spines_to_remove:
    ax.spines[spine].set_visible(False)
    
ax.set_ylim(4, 12.5)
fig.savefig('ssDNA_e_to_e_17.png', dpi=300, bbox_inches='tight')

# %%
list = ['40_7_CH_REP_1.8', '40_0_CH_REP_1.8']
length = ['DIH = 0.7', 'DIH = 0.0' ]

xtick_pos = np.array([0, 1])
cmap = sns.color_palette("Set2")

data0_18, median_dna_18, std_dna_18 =[], [], []

for ll in list:
    name="/trajectories/gargi/RPA_Ed/RESULTS.ANALYSIS/end_to_end_"+ll+".txt"
    data = np.loadtxt(name)
    mask = np.isnan(data)
    data_n = data[~mask]
    #data_n = data_n[data_n < 100.0]
    dt=data_n/10
    me1=np.median(dt)
    sd1=np.std(dt)
    median_dna_18.append(me1)
    std_dna_18.append(sd1)
    data0_18.append(dt)
    
fig, ax = plt.subplots(figsize=(12,8))
    
sns.violinplot(data=data0_18, width=0.8, ax=ax, palette=cmap, split=True, scale="width")
ax.set_xticks(xtick_pos, length, fontsize=24, rotation = 45)
ax.set_ylabel('Distance (nm)', fontsize=28)

ax.set_title('Radius = 1.8', fontsize=30, fontweight='bold')
ax.xaxis.tick_bottom()
ax.yaxis.tick_left()
ax.tick_params(axis='both', which='major', labelsize=22)

spines_to_keep = ['bottom', 'left']
spines_to_remove = ['top', 'right']

for spine in spines_to_remove:
    ax.spines[spine].set_visible(False)

# %%
fig, ax = plt.subplots(figsize=(12,8))
length = ['k$_{D}$ = 0.7', 'k$_{D}$ = 0.0']
    
x = [0, 1]
rects = ax.bar(x, median_dna_18, width=0.25, yerr=std_dna_18, label=median_dna_18,capsize=6)
ax.bar_label(rects, fmt='%3.2f', padding=3, fontsize=24, fontweight='bold')
ax.set_xticks(xtick_pos, length, fontsize=24, fontweight='bold')
ax.set_ylabel('Distance (nm)', fontsize=28)

ax.set_title('Radius = 1.8 A', fontsize=30, fontweight='bold')
ax.xaxis.tick_bottom()
ax.yaxis.tick_left()
ax.tick_params(axis='both', which='major', labelsize=22)

spines_to_keep = ['bottom', 'left']
spines_to_remove = ['top', 'right']

for spine in spines_to_remove:
    ax.spines[spine].set_visible(False)
    
ax.set_ylim(4, 12.5)
fig.savefig('ssDNA_e_to_e_18.png', dpi=300, bbox_inches='tight')

# %%
list = ['40_7_LOWSALT', '40_0_LOWSALT']
length = ['DIH = 0.7', 'DIH = 0.0' ]

xtick_pos = np.array([0, 1])
cmap = sns.color_palette("Set2")

data0_20, median_dna_20, std_dna_20 =[], [], []

for ll in list:
    name="/trajectories/gargi/RPA_Ed/RESULTS.ANALYSIS/end_to_end_"+ll+".txt"
    data = np.loadtxt(name)
    mask = np.isnan(data)
    data_n = data[~mask]
    #data_n = data_n[data_n < 100.0]
    dt=data_n/10
    me1=np.median(dt)
    sd1=np.std(dt)
    median_dna_20.append(me1)
    std_dna_20.append(sd1)
    data0_20.append(dt)
    
fig, ax = plt.subplots(figsize=(12,8))
    
sns.violinplot(data=data0_20, width=0.8, ax=ax, palette=cmap, split=True, scale="width")
ax.set_xticks(xtick_pos, length, fontsize=24, rotation = 45)
ax.set_ylabel('Distance (nm)', fontsize=28)

ax.set_title('Radius = 2.0', fontsize=30, fontweight='bold')
ax.xaxis.tick_bottom()
ax.yaxis.tick_left()
ax.tick_params(axis='both', which='major', labelsize=22)

spines_to_keep = ['bottom', 'left']
spines_to_remove = ['top', 'right']

for spine in spines_to_remove:
    ax.spines[spine].set_visible(False)

# %%
fig, ax = plt.subplots(figsize=(12,8))
length = ['k$_{D}$ = 0.7', 'k$_{D}$ = 0.0']
    
x = [0, 1]
rects = ax.bar(x, median_dna_20, width=0.25, yerr=std_dna_20, label=median_dna_20,capsize=6)
ax.bar_label(rects, fmt='%3.2f', padding=3, fontsize=24, fontweight='bold')
ax.set_xticks(xtick_pos, length, fontsize=24, fontweight='bold')
ax.set_ylabel('Distance (nm)', fontsize=28)

ax.set_title('Radius = 2.0 A', fontsize=30, fontweight='bold')
ax.xaxis.tick_bottom()
ax.yaxis.tick_left()
ax.tick_params(axis='both', which='major', labelsize=22)

spines_to_keep = ['bottom', 'left']
spines_to_remove = ['top', 'right']

for spine in spines_to_remove:
    ax.spines[spine].set_visible(False)
    
ax.set_ylim(4, 12.5)
fig.savefig('ssDNA_e_to_e_20.png', dpi=300, bbox_inches='tight')

# %%
x = [30, 1000]
fig, ax = plt.subplots(figsize=(10,8))
ax.scatter(x, median_dna_20, label='radius = 2.0', s=200, edgecolor = 'black')
ax.scatter(x, median_dna_18, label='radius = 1.8', s=200, edgecolor = 'black')
ax.scatter(x, median_dna_17, label='radius = 1.7', s=200, edgecolor = 'black')
ax.scatter(x, median_dna_16, label='radius = 1.6', s=200, edgecolor = 'black')
ax.scatter(x, median_dna_15, label='radius = 1.5', s=200, edgecolor = 'black')
'''
ax.errorbar(x, median_dna_20, yerr=std_dna_20, capsize=6)
ax.errorbar(x, median_dna_18, yerr=std_dna_20, capsize=6)
ax.errorbar(x, median_dna_17, yerr=std_dna_20, capsize=6)
ax.errorbar(x, median_dna_16, yerr=std_dna_20, capsize=6)
ax.errorbar(x, median_dna_15, yerr=std_dna_20, capsize=6)
'''
ax.plot(x, median_dna_20)
ax.plot(x, median_dna_18)
ax.plot(x, median_dna_17)
ax.plot(x, median_dna_16)
ax.plot(x, median_dna_15)


ax.legend(fontsize=20)
ax.set_ylabel('Distance (nm)', fontsize=28)
ax.set_xlabel('Salt (mM)', fontsize=28)

#ax.set_title('Radius = 2.0 A', fontsize=30, fontweight='bold')
ax.xaxis.tick_bottom()
ax.yaxis.tick_left()
ax.tick_params(axis='both', which='major', labelsize=22)

spines_to_keep = ['bottom', 'left']
spines_to_remove = ['top', 'right']

for spine in spines_to_remove:
    ax.spines[spine].set_visible(False)
    
ax.set_ylim(58, 72)
    
fig.savefig('distance_salt.png', dpi=300, bbox_inches='tight')

# %%
x = [30, 1000]
fig, ax = plt.subplots(figsize=(10,8))
ax.scatter(x, median_dna_20, label='radius = 2.0', s=200, edgecolor = 'black')
ax.scatter(x, median_dna_18, label='radius = 1.8', s=200, edgecolor = 'black')
ax.scatter(x, median_dna_17, label='radius = 1.7', s=200, edgecolor = 'black')
ax.scatter(x, median_dna_16, label='radius = 1.6', s=200, edgecolor = 'black')
ax.scatter(x, median_dna_15, label='radius = 1.5', s=200, edgecolor = 'black')

ax.plot(x, median_dna_20)
ax.plot(x, median_dna_18)
ax.plot(x, median_dna_17)
ax.plot(x, median_dna_16)
ax.plot(x, median_dna_15)


ax.legend(fontsize=20)
ax.set_ylabel('Distance (nm)', fontsize=28)
ax.set_xlabel('Salt (mM)', fontsize=28)

#ax.set_title('Radius = 2.0 A', fontsize=30, fontweight='bold')
ax.xaxis.tick_bottom()
ax.yaxis.tick_left()
ax.tick_params(axis='both', which='major', labelsize=22)

spines_to_keep = ['bottom', 'left']
spines_to_remove = ['top', 'right']

for spine in spines_to_remove:
    ax.spines[spine].set_visible(False)
    
ax.set_ylim(5.8, 7.4)
    
fig.savefig('distance_salt.png', dpi=300, bbox_inches='tight')
